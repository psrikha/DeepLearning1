# %%
import torch 
import torchvision
from torch.utils.data import Dataset, DataLoader    
import torch.autograd as autograd       
from torch import Tensor                
import torch.nn as nn                   
import torch.nn.functional as F         
import torch.optim as optim             
from torch.jit import script, trace     
from torchvision import datasets, models, transforms    
import torchvision.transforms as transforms             

# Hyperparameters
n_epochs = 5
num_classes = 10
batch_size = 10
learning_rate = 0.001

DATA_PATH = '/Users/avinash/dataset/'
MODEL_STORE_PATH = '/Users/avinash/models'

trans = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])

# MNIST dataset
train_dataset = torchvision.datasets.MNIST(root=DATA_PATH, train=True, transform=trans, download=True)
test_dataset = torchvision.datasets.MNIST(root=DATA_PATH, train=False, transform=trans,download=True)
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

class Avinash(nn.Module):
    def __init__(self):
        super(Avinash, self).__init__()
        self.Avinashlayer1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.Avinashlayer2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.drop_out = nn.Dropout()
        self.fc1 = nn.Linear(7 * 7 * 64, 1000)
        self.fc2 = nn.Linear(1000, 10)

    def forward(self, x):
        out = self.Avinashlayer1(x)
        out = self.Avinashlayer2(out)
        out = out.reshape(out.size(0), -1)
        out = self.drop_out(out)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

model = Avinash()

pytorch_total_params = sum(p.numel() for p in model.parameters())
print(pytorch_total_params)
# Out:
# ...
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting /Users/avinash/dataset/MNIST/raw/train-images-idx3-ubyte.gz to /Users/avinash/dataset/MNIST/raw
#
# ...
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting /Users/avinash/dataset/MNIST/raw/train-labels-idx1-ubyte.gz to /Users/avinash/dataset/MNIST/raw
#
# ...
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting /Users/avinash/dataset/MNIST/raw/t10k-images-idx3-ubyte.gz to /Users/avinash/dataset/MNIST/raw
#
# ...
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting /Users/avinash/dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz to /Users/avinash/dataset/MNIST/raw
#
# 3199106

# %%
class Avinash2(nn.Module):
    def __init__(self):
        super(Avinash2, self).__init__()
        self.Avinashlayer1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.Avinashlayer2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.drop_out = nn.Dropout()
        self.fc1 = nn.Linear(7 * 7 * 64, 200)
        self.fc2 = nn.Linear(200, 10)

    def forward(self, x):
        out = self.Avinashlayer1(x)
        out = self.Avinashlayer2(out)
        out = out.reshape(out.size(0), -1)
        out = self.drop_out(out)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

Avinash2 =Avinash2()

pytorch_total_param2 = sum(p.numel() for p in Avinash2.parameters())
print(pytorch_total_param2)
# Out:
# 681506

# %%
class Avinash3(nn.Module):
    def __init__(self):
        super(Avinash3, self).__init__()
        self.Avinashlayer1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.drop_out = nn.Dropout()
        self.fc1 = nn.Linear(7 * 7 * 64, 500)
        self.fc2 = nn.Linear(500, 10)

    def forward(self, x):
        out = self.Avinashlayer1(x)
        out = out.reshape(out.size(0), -1)
        out = self.drop_out(out)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

Avinash3 =Avinash3()

pytorch_total_param3 = sum(p.numel() for p in Avinash3.parameters())
print(pytorch_total_param3)
# Out:
# 1574342

# %%
class Avinash4(nn.Module):
    def __init__(self):
        super(Avinash4, self).__init__()
        self.Avinashlayer1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.drop_out = nn.Dropout()
        self.fc1 = nn.Linear(7 * 7 * 64, 700)
        self.fc2 = nn.Linear(700, 100)
        self.fc3=nn.Linear(100,10)

    def forward(self, x):
        out = self.Avinashlayer1(x)
        out = out.reshape(out.size(0), -1)
        out = self.drop_out(out)
        out = self.fc1(out)
        out = self.fc2(out)
        out=self.fc3(out)
        return out

Avinash4 =Avinash4()

pytorch_total_param4 = sum(p.numel() for p in Avinash4.parameters())
print(pytorch_total_param4)
# Out:
# 2267842

# %%
class Avinash5(nn.Module):
    def __init__(self):
        super(Avinash5, self).__init__()
        self.Avinashlayer1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.drop_out = nn.Dropout()
        self.fc1 = nn.Linear(7 * 7 * 64, 20)
        self.fc2 = nn.Linear(20, 50)
        self.fc3=nn.Linear(50,10)

    def forward(self, x):
        out = self.Avinashlayer1(x)
        out = out.reshape(out.size(0), -1)
        out = self.drop_out(out)
        out = self.fc1(out)
        out = self.fc2(out)
        out=self.fc3(out)
        return out

Avinash5 =Avinash5()

pytorch_total_param5 = sum(p.numel() for p in Avinash5.parameters())
print(pytorch_total_param5)
# Out:
# 65132

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
optimizer2 = torch.optim.Adam(Avinash2.parameters(), lr=learning_rate)



# Train the model
total_step = len(train_loader)
loss_list = []
acc_list = []

# %%
for epoch in range(1):
    for i, data in enumerate(train_loader):
        images,labels=data
        outputs=model(images)
        
        optimizer.zero_grad()
       
        loss1=criterion(outputs, labels)
        
        loss_list.append(loss1.item())        
        optimizer.zero_grad()
        
        loss1.backward()
       
        optimizer.step()
        

        print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1000
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 1035
# 1036
# 1037
# 1038
# 1039
# 1040
# 1041
# 1042
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1051
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1065
# 1066
# 1067
# 1068
# 1069
# 1070
# 1071
# 1072
# 1073
# 1074
# 1075
# 1076
# 1077
# 1078
# 1079
# 1080
# 1081
# 1082
# 1083
# 1084
# 1085
# 1086
# 1087
# 1088
# 1089
# 1090
# 1091
# 1092
# 1093
# 1094
# 1095
# 1096
# 1097
# 1098
# 1099
# 1100
# 1101
# 1102
# 1103
# 1104
# 1105
# 1106
# 1107
# 1108
# 1109
# 1110
# 1111
# 1112
# 1113
# 1114
# 1115
# 1116
# 1117
# 1118
# 1119
# 1120
# 1121
# 1122
# 1123
# 1124
# 1125
# 1126
# 1127
# 1128
# 1129
# 1130
# 1131
# 1132
# 1133
# 1134
# ...

# %%
for epoch in range(1):
    for i, data in enumerate(train_loader):
        images,labels=data
    
        outputs2=Avinash2(images)

        
        optimizer2.zero_grad()
      
        
        loss2=criterion(outputs2,labels)
        
        loss_list.append(loss2.item())



        # Backprop and perform Adam optimisation
     
        optimizer2.zero_grad()

     
        loss2.backward()
      
        optimizer2.step()

# %%
optimizer3 = torch.optim.Adam(Avinash3.parameters(), lr=learning_rate)

# %%
for epoch in range(1):
    for i, data in enumerate(train_loader):
        images,labels=data
    
        outputs3=Avinash3(images)
      
        
        optimizer3.zero_grad()
      
        
        loss3=criterion(outputs3,labels)
        
        loss_list.append(loss3.item())



        # Backprop and perform Adam optimisation
     
        optimizer3.zero_grad()

     
        loss3.backward()
      
        optimizer3.step()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-3344bfb7b2bf> in <module>
#       3         images,labels=data
#       4
# ----> 5         outputs3=Avinash3(images)
#       6
#       7
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-11-014c8aefebec> in forward(self, x)
#      14         out = out.reshape(out.size(0), -1)
#      15         out = self.drop_out(out)
# ...

# %%
for epoch in range(2):
    for i, data in enumerate(train_loader):
        images,labels=data
        outputs=model(images)
        outputs2=Avinash2(images)
        # outputs3=manish3(images)
        optimizer.zero_grad()
        optimizer2.zero_grad()
        # optimier3.zero_grad()
        loss1=criterion(outputs, labels)
        loss2=criterion(outputs2,labels)
        # loss3=criterion(outputs3,labels)
        loss_list.append(loss1.item())        
        loss_list.append(loss2.item())
        # loss_list.append(loss3.item())



        # Backprop and perform Adam optimisation
        optimizer.zero_grad()
        optimizer2.zero_grad()
        # optimizer3.zero_grad()
        loss1.backward()
        loss2.backward()
        # loss3.backward()
        optimizer.step()
        optimizer2.step()

# %%
model.eval()
acc=[]
with torch.no_grad():
    corr = 0
    tot = 0
    for images, labels in test_loader:
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        tot = tot+labels.size(0)
        corr = corr+ (predicted == labels).sum().item()
        acc.append(corr/tot)

    print('Test Accuracy of the evaluated model on the 10000 images tested: {} %'.format((corr / tot) * 100))

# Save the model and plot
torch.save(model.state_dict(), MODEL_STORE_PATH + 'conv_net_model.ckpt')
# Out:
# Test Accuracy of the evaluated model on the 10000 images tested: 98.47 %

# %%
valid_loss_list=[]
for input, pred in test_loader:
        output = model(input)
        loss = F.poisson_nll_loss(output,pred)
        valid_loss_list.append(loss.item())

# %%
import matplotlib.pyplot as plt
plt.plot(loss_list,label='Loss')
plt.plot(acc,label='Accuracy')
plt.xlabel('Parameters')
plt.ylabel('Loss')
plt.legend()

# %%
plt.plot(acc)
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')
